# %% [markdown]
# **DYNOTEARS: Structure Learning from Time-Series Data**

# %% [markdown]
#  S&P 100 stock returns
# We apply DYNOTEARS to a financial dataset of daily
# stock returns of companies in the S&P 100. The dataset
# was obtained using the yahoofinancials1 Python
# package and consists of daily closing prices from 1 July
# 2014 to 30 June 2019, inclusive.

# %% [markdown]
# DREAM4 gene expression data
# We benchmark DYNOTEARS on the DREAM4 network inference challenge (Marbach et al., 2009), in
# which the objective is to learn gene regulatory networks from gene expression data. DREAM4 consists
# of 5 independent datasets, each with 10 different timeseries recordings for 100 genes across 21 time steps

# %% [markdown]
# ![image.png](attachment:f5c13da2-6909-49c1-90af-110942dc3dcc.png)
# We assume that variables influence each other in both a contemporaneous and a time-lagged manner, as illustrated in Figure 1.
# We call these intra-slice and inter-slice dependencies, respectively.

# %% [markdown]
# **Detecting and quantifying causal associations in large nonlinear time series datasets**
#
# https://www.science.org/doi/full/10.1126/sciadv.aau4996
#
# https://github.com/jakobrunge/tigramite/

# %%
# !python --version
# Out:
# Python 3.10.9
